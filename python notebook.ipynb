# %%
# %matplotlib inline  
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2;
img1 = cv2.imread('1_org.jpg')
i1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(i1, cmap = 'gray', interpolation = 'bicubic')

# %%
plt.imshow(i1)

# %% [markdown]
# ## Edge detection

# %%
imagePath = '1_org.jpg'
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)
height, width = blurred.shape[:2]
blurred = cv2.resize(blurred,(width/10, height/10), interpolation = cv2.INTER_CUBIC)

# apply Canny edge detection using a wide threshold, tight
# threshold, and automatically determined threshold
wide = cv2.Canny(blurred, 10, 200)
tight = cv2.Canny(blurred, 225, 250)

# %%
plt.imshow(wide,cmap = 'gray')

# %%
plt.imshow(tight,cmap = 'gray')

# %% [markdown]
# ## Resize

# %%
 height, width = image.shape[:2]
 res = cv2.resize(image,(width/10, height/10), interpolation = cv2.INTER_CUBIC)

# %% [markdown]
# ## Hough Line transform

# %%
from skimage.filters import rank
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-69-30187d6f78d7> in <module>()
# ----> 1 from skimage.filters import rank
#
# ImportError: No module named skimage.filters

# %%
imagePath = 'lcntest2.png'
image = cv2.imread(imagePath, cv2.COLOR_BGR2GRAY)

# %%
np.ndarray(image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-3581db9608db> in <module>()
# ----> 1 np.ndarray(image)
#
# ValueError: sequence too large; must be smaller than 32
